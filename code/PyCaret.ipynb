# %%
from pycaret.classification import *
exp1 = setup(train, target = 'label', ignore_features=['customer_id', 'year_month'])
# Out:
# <style  type="text/css" >
# </style><table id="T_0b85d214_a02d_11eb_8fad_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b85d214_a02d_11eb_8fad_0242ac110002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0b85d214_a02d_11eb_8fad_0242ac110002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_0b85d214_a02d_11eb_8fad_0242ac110002row0_col1" class="data row0 col1" >1974</td>
#             </tr>
#             <tr>
#                         <th id="T_0b85d214_a02d_11eb_8fad_0242ac110002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0b85d214_a02d_11eb_8fad_0242ac110002row1_col0" class="data row1 col0" >Target</td>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_ec36c03e_a02d_11eb_8fad_0242ac110002 th {
#           text-align: left;
# ...

# %%
cboost = create_model('catboost')
# Out:
# <style  type="text/css" >
# #T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col0,#T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col1,#T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col2,#T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col3,#T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col4,#T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col5,#T_42c7e806_a02e_11eb_8fad_0242ac110002row10_col6{
#             background:  yellow;
#         }</style><table id="T_42c7e806_a02e_11eb_8fad_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tuned_cboost = tune_model(cboost)
# Out:
# <style  type="text/css" >
# #T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col0,#T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col1,#T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col2,#T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col3,#T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col4,#T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col5,#T_f3bf6170_a02e_11eb_8fad_0242ac110002row10_col6{
#             background:  yellow;
#         }</style><table id="T_f3bf6170_a02e_11eb_8fad_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
plot_model(estimator = tuned_cboost, plot = 'auc')

# %%
plot_model(estimator = tuned_cboost, plot = 'confusion_matrix')

# %%
plot_model(estimator = tuned_cboost, plot = 'feature')

# %%
evaluate_model(tuned_cboost)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
